# %% [markdown]
# # Part 1 of 3

# %% [markdown]
# ### Import files and connect to page

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Webscape data from wikipedia

# %%
import urllib.request
from bs4 import BeautifulSoup

url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
page = urllib.request.urlopen(url)

soup = BeautifulSoup(page, "lxml")
#all_tables=soup.find_all("table")
right_table=soup.find('table', class_='wikitable sortable')

# %% [markdown]
# ### Loop through correct table and get all data

# %%
A=[]
B=[]
C=[]

for row in right_table.findAll('tr'):
    cells=row.findAll('td')
    if len(cells)==3:
        A.append(cells[0].find(text=True))
        B.append(cells[1].find(text=True))
        C.append(cells[2].find(text=True))

# %% [markdown]
# ### once data is retrieved fit into pandas dataframe

# %%
df=pd.DataFrame(A,columns=['Postcode'])
df['Borough']=B
df['Neighbourhood']=C
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned     Not assigned
#
# 1      M2A      Not assigned     Not assigned
#
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %% [markdown]
# ### Drop all Borough with "Not assigned"

# %%
df = df[df.Borough != 'Not assigned']
df.head(20)
# Out:
#    Postcode           Borough     Neighbourhood
# 2       M3A        North York         Parkwoods
# 3       M4A        North York  Victoria Village
# 4       M5A  Downtown Toronto      Harbourfront
# 5       M6A        North York  Lawrence Heights
# 6       M6A        North York    Lawrence Manor
# 7       M7A  Downtown Toronto      Queen's Park
# 9       M9A      Queen's Park     Not assigned
#
# 10      M1B       Scarborough             Rouge
# 11      M1B       Scarborough           Malvern
# 13      M3B        North York  Don Mills North
#
# 14      M4B         East York  Woodbine Gardens
# 15      M4B         East York     Parkview Hill
# 16      M5B  Downtown Toronto          Ryerson
#
# 17      M5B  Downtown Toronto  Garden District
#
# 18      M6B        North York        Glencairn
#
# 21      M9B         Etobicoke       Cloverdale
#
# 22      M9B         Etobicoke         Islington
# 23      M9B         Etobicoke     Martin Grove
#
# 24      M9B         Etobicoke  Princess Gardens
# 25      M9B         Etobicoke   West Deane Park

# %% [markdown]
# ### Remove special characters and using where choose either borough or neighbourhood

# %%
df['Neighbourhood'] = df['Neighbourhood'].str.strip()
df['NewCol'] = np.where(df['Neighbourhood']=='Not assigned', df['Borough'], df['Neighbourhood'])
df.head(15)
#df[df['Neighbourhood']=='Not assigned']
# Out:
#    Postcode           Borough     Neighbourhood            NewCol
# 2       M3A        North York         Parkwoods         Parkwoods
# 3       M4A        North York  Victoria Village  Victoria Village
# 4       M5A  Downtown Toronto      Harbourfront      Harbourfront
# 5       M6A        North York  Lawrence Heights  Lawrence Heights
# 6       M6A        North York    Lawrence Manor    Lawrence Manor
# 7       M7A  Downtown Toronto      Queen's Park      Queen's Park
# 9       M9A      Queen's Park      Not assigned      Queen's Park
# 10      M1B       Scarborough             Rouge             Rouge
# 11      M1B       Scarborough           Malvern           Malvern
# 13      M3B        North York   Don Mills North   Don Mills North
# 14      M4B         East York  Woodbine Gardens  Woodbine Gardens
# 15      M4B         East York     Parkview Hill     Parkview Hill
# 16      M5B  Downtown Toronto           Ryerson           Ryerson
# 17      M5B  Downtown Toronto   Garden District   Garden District
# 18      M6B        North York         Glencairn         Glencairn

# %% [markdown]
# ### Delete old column, rename new column

# %%
df.rename(columns={'Neighbourhood': 'OldCol', 'NewCol': 'Neighbourhood'}, inplace=True)
del df['OldCol']
df[1:10]
# Out:
#    Postcode           Borough     Neighbourhood
# 3       M4A        North York  Victoria Village
# 4       M5A  Downtown Toronto      Harbourfront
# 5       M6A        North York  Lawrence Heights
# 6       M6A        North York    Lawrence Manor
# 7       M7A  Downtown Toronto      Queen's Park
# 9       M9A      Queen's Park      Queen's Park
# 10      M1B       Scarborough             Rouge
# 11      M1B       Scarborough           Malvern
# 13      M3B        North York   Don Mills North

# %% [markdown]
# ### M9A is now no longer 'Not assigned'

# %%
df.shape
# Out:
# (210, 3)

# %% [markdown]
# # Part 2 of 3

# %% [markdown]
# ### Import Geospatial csv

# %%
# !wget -O Geospatial_Coordinates.csv https://cocl.us/Geospatial_data/Geospatial_Coordinates.csv
dfCor = pd.read_csv('Geospatial_Coordinates.csv')
# Out:
# --2020-01-31 04:21:40--  https://cocl.us/Geospatial_data/Geospatial_Coordinates.csv
# Resolving cocl.us (cocl.us)... 169.48.113.194, 158.85.108.86, 158.85.108.83
# Connecting to cocl.us (cocl.us)|169.48.113.194|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-01-31 04:21:43--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 107.152.26.197, 107.152.27.197
# Connecting to ibm.box.com (ibm.box.com)|107.152.26.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-01-31 04:21:43--  https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Reusing existing connection to ibm.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-01-31 04:21:43--  https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 107.152.26.211, 107.152.27.211
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|107.152.26.211|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!ZY8a3sjZzxTePNZ9xsNxU2jHYkIMys-QUViQDy_PGvHIDDdD0e_nMG-RUT6qkhrA_k8FpILCR_a7eTLbHkPzgJ0gVmmGpAIT_CznTBZ4lNbUyMPjtt3HLpqP8rPM4tWpVWOM6IpH6LkqUri5OgxxV-hNMGiNkYqgrwbzVAQ0p03hQFrWfZVDhTfTIL7IUeJ1R51z6dzRsUxf7P3aN52Wf-3_KeE_ntsazZgcWnCNdHhqExRjME_espZvAhwx0lB49ZAk3X_e-cXc-wZlL7c7TMFHyscQ7psICR5LDAQBZ2_P3a9aXpZGTbByh5gLTRiBNIAW2v6s4llb_2t-U9-N6bN6-EQdSEkr-Y4HW-NDP73tUkuOIjwpR6btOA6xPfwGYLr5ic8_8zSOJHAOKar5VihW5RCeMNoetqjNIjdIvUH7XUxPYVnf1Q-Mp2XEWrh6YFQesOOz0N2t5zFK-oR2hRbTwe4pdUF_jF_iXb7iA_-8_CRYTnd1sNeeG--1deu9jJUW_eANFIiFrHgn7FpxgBH85uW5DjvfYnya5Uh6mItPde3EWrZ0OwZUBvhNBaEnKAxqSf72o3ajGvRJbDP8LvdQGviee26V5R3exp-l5NObJcsG8cD6hvbHbjqmTQ8tct0pzHtVVCX3r9mbrIIK-mapxO5AaY7XdCujw682x2yrwmIao9eRFrwiic-mQKNcybya0t4WZbssIP87Yr67mCZipV681l_aeQSSq-gtqnrVokkpr4kzXOYWX-CA1OQMAbn0GhMEbHAldmzaK8FN8uI9r-34tynkGA3jiqrF6w1Cg4KNOeLwswy2U0M0tZIqlPHIg0PxwkjSsGbjSetRkbyDvmqyKLXudjz3xYTJv9lIbdoBkI6X90HYDjYMYnbDGwB5-DAAfiClQbOiF2edIf4tMv6XBdDmUp4M-cEJ-sp8CczpR07RXlX_pKaIVZgXv_mTJS0HC2WzFLGvpSdyigJSsEcx7PkuP5wub3ldOK9PnCRZcfc2GWJEWL9s6_dxNmFN6OTe1DmFds2letFL6-2NxvmPfrnm5CX1VoGphW4JTwE_VcP8kzyoWlLbBHeJEs8lB84gQzUQf-beDKG0T5CMQsRVERFln7f8iyrkO8YlmKiv5YTDRNXc0Lke5UfHhEIrNTZ7LU_DduEDYrSnFL_lD6HqyCVODcO4cL2nghyfUTP8ZDGeJgJT8ffRNiaahVyAi3YFeAkcgef57kYk8L4_NLD7FLo3m_xouL_A2LKQmY1MK3Kxvf1MzPWDltaoSsUjuF187MUCUJ-9CrXW73Qnx3UIo51Zhbpa48Uoz4c07d5EHnP_YDZ0OL1TZX19XwKJCqq_16U0Wel3TrDnP8fWDX41hqscqcK_pv6lPgIVee4cSE5B9udI9mg./download [following]
# --2020-01-31 04:21:44--  https://public.boxcloud.com/d/1/b1!ZY8a3sjZzxTePNZ9xsNxU2jHYkIMys-QUViQDy_PGvHIDDdD0e_nMG-RUT6qkhrA_k8FpILCR_a7eTLbHkPzgJ0gVmmGpAIT_CznTBZ4lNbUyMPjtt3HLpqP8rPM4tWpVWOM6IpH6LkqUri5OgxxV-hNMGiNkYqgrwbzVAQ0p03hQFrWfZVDhTfTIL7IUeJ1R51z6dzRsUxf7P3aN52Wf-3_KeE_ntsazZgcWnCNdHhqExRjME_espZvAhwx0lB49ZAk3X_e-cXc-wZlL7c7TMFHyscQ7psICR5LDAQBZ2_P3a9aXpZGTbByh5gLTRiBNIAW2v6s4llb_2t-U9-N6bN6-EQdSEkr-Y4HW-NDP73tUkuOIjwpR6btOA6xPfwGYLr5ic8_8zSOJHAOKar5VihW5RCeMNoetqjNIjdIvUH7XUxPYVnf1Q-Mp2XEWrh6YFQesOOz0N2t5zFK-oR2hRbTwe4pdUF_jF_iXb7iA_-8_CRYTnd1sNeeG--1deu9jJUW_eANFIiFrHgn7FpxgBH85uW5DjvfYnya5Uh6mItPde3EWrZ0OwZUBvhNBaEnKAxqSf72o3ajGvRJbDP8LvdQGviee26V5R3exp-l5NObJcsG8cD6hvbHbjqmTQ8tct0pzHtVVCX3r9mbrIIK-mapxO5AaY7XdCujw682x2yrwmIao9eRFrwiic-mQKNcybya0t4WZbssIP87Yr67mCZipV681l_aeQSSq-gtqnrVokkpr4kzXOYWX-CA1OQMAbn0GhMEbHAldmzaK8FN8uI9r-34tynkGA3jiqrF6w1Cg4KNOeLwswy2U0M0tZIqlPHIg0PxwkjSsGbjSetRkbyDvmqyKLXudjz3xYTJv9lIbdoBkI6X90HYDjYMYnbDGwB5-DAAfiClQbOiF2edIf4tMv6XBdDmUp4M-cEJ-sp8CczpR07RXlX_pKaIVZgXv_mTJS0HC2WzFLGvpSdyigJSsEcx7PkuP5wub3ldOK9PnCRZcfc2GWJEWL9s6_dxNmFN6OTe1DmFds2letFL6-2NxvmPfrnm5CX1VoGphW4JTwE_VcP8kzyoWlLbBHeJEs8lB84gQzUQf-beDKG0T5CMQsRVERFln7f8iyrkO8YlmKiv5YTDRNXc0Lke5UfHhEIrNTZ7LU_DduEDYrSnFL_lD6HqyCVODcO4cL2nghyfUTP8ZDGeJgJT8ffRNiaahVyAi3YFeAkcgef57kYk8L4_NLD7FLo3m_xouL_A2LKQmY1MK3Kxvf1MzPWDltaoSsUjuF187MUCUJ-9CrXW73Qnx3UIo51Zhbpa48Uoz4c07d5EHnP_YDZ0OL1TZX19XwKJCqq_16U0Wel3TrDnP8fWDX41hqscqcK_pv6lPgIVee4cSE5B9udI9mg./download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.24.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.24.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2891 (2.8K) [text/csv]
# Saving to: ‘Geospatial_Coordinates.csv’
#
# 100%[======================================>] 2,891       --.-K/s   in 0s
#
# 2020-01-31 04:21:44 (252 MB/s) - ‘Geospatial_Coordinates.csv’ saved [2891/2891]

# %% [markdown]
# ### Rename column so they can join

# %%
dfCor.rename(columns={'Postal Code': 'Postcode'}, inplace=True)

# %%
#dfnew = pd.merge(df,dfCor,by = "Postcode",all.x = TRUE)
dfnew = df.merge(dfCor, on='Postcode')
dfnew.head()
# Out:
#   Postcode           Borough     Neighbourhood   Latitude  Longitude
# 0      M3A        North York         Parkwoods  43.753259 -79.329656
# 1      M4A        North York  Victoria Village  43.725882 -79.315572
# 2      M5A  Downtown Toronto      Harbourfront  43.654260 -79.360636
# 3      M6A        North York  Lawrence Heights  43.718518 -79.464763
# 4      M6A        North York    Lawrence Manor  43.718518 -79.464763

# %%
#import geocoder # import geocoder

# initialize your variable to None
#lat_lng_coords = None

# loop until you get the coordinates
#while(lat_lng_coords is None):
#  g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
#  lat_lng_coords = g.latlng

#latitude = lat_lng_coords[0]
#longitude = lat_lng_coords[1]

# %% [markdown]
# # Part 3 of 3

# %% [markdown]
# ### Download dependencies

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import requests # library to handle requests

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library
# Out:
# Solving environment: done
#
# # All requested packages already installed.

# %% [markdown]
# ### Only boroughs with "Toronto"

# %%
dfTor = dfnew[dfnew['Borough'].str.contains("Toronto")]
dfTor.head(10)
# Out:
#    Postcode           Borough       Neighbourhood   Latitude  Longitude
# 2       M5A  Downtown Toronto        Harbourfront  43.654260 -79.360636
# 5       M7A  Downtown Toronto        Queen's Park  43.662301 -79.389494
# 12      M5B  Downtown Toronto             Ryerson  43.657162 -79.378937
# 13      M5B  Downtown Toronto     Garden District  43.657162 -79.378937
# 26      M5C  Downtown Toronto      St. James Town  43.651494 -79.375418
# 35      M4E      East Toronto         The Beaches  43.676357 -79.293031
# 36      M5E  Downtown Toronto         Berczy Park  43.644771 -79.373306
# 40      M5G  Downtown Toronto  Central Bay Street  43.657952 -79.387383
# 41      M6G  Downtown Toronto            Christie  43.669542 -79.422564
# 48      M5H  Downtown Toronto            Adelaide  43.650571 -79.384568

# %%
# create map of Toronto using latitude and longitude values
map_tor = folium.Map(location=[43.715, -79.38355], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(dfTor['Latitude'], dfTor['Longitude'], dfTor['Borough'], dfTor['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_tor)  
    
map_tor
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
